# %% [markdown]
# <a href="https://colab.research.google.com/github/jfernandezp/EjemploDataScience/blob/main/Clase1_DD2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1
# Out:
# 2

# %%
#@title Texto de título predeterminado
print("hola mundo")
# Out:
# hola mundo

# %%
import time
start = time.time()
print ("process")
time_elapsed = time.time() - start
codigo = "1235642"
print("El tiempo de demora es " + str(time_elapsed) + " segundos")
print(f"El tiempo de demora es {time_elapsed} segundos")
# Out:
# process
# El tiempo de demora es 0.00010967254638671875 segundos
# El tiempo de demora es 0.00010967254638671875 segundos

# %%
for i in range(10):
  if(i%3 == 0):
    print(f"{i} es muliplo de 3")
# Out:
# 0 es muliplo de 3
# 3 es muliplo de 3
# 6 es muliplo de 3
# 9 es muliplo de 3

# %%
r = range(10)
for i in filter(lambda x: x % 2 == 0, r):
  print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
for i in range(0,20, 3):
  if i%2 == 0:
    print(f"{i} es par")
  else:
    print(f"{i} es impar")
# Out:
# 0 es par
# 3 es impar
# 6 es par
# 9 es impar
# 12 es par
# 15 es impar
# 18 es par

# %%
import pandas as pd

pddf = pd.DataFrame({'nombre' : ['Julio', 'Javier', 'Miluska', 'Deysi', 'Karla', 'Juan'], 
                    'nota': [16, 17, 20, 18, 14, 11]})

# %%
pddf
# Out:
#     nombre  nota
# 0    Julio    16
# 1   Javier    17
# 2  Miluska    20
# 3    Deysi    18
# 4    Karla    14
# 5     Juan    11

# %%
pddf['Col_new'] = [13, 45, 56, 23, 45, 87]
pddf
# Out:
#     nombre  nota  Col_new
# 0    Julio    16       13
# 1   Javier    17       45
# 2  Miluska    20       56
# 3    Deysi    18       23
# 4    Karla    14       45
# 5     Juan    11       87

# %%
pddf['col_new2'] = pddf['nota'] * 2
pddf
# Out:
#     nombre  nota  Col_new  col_new2
# 0    Julio    16       13        32
# 1   Javier    17       45        34
# 2  Miluska    20       56        40
# 3    Deysi    18       23        36
# 4    Karla    14       45        28
# 5     Juan    11       87        22

# %%
df = pddf.loc[pddf['nota']<=14, ['nombre','col_new2']]
df
# Out:
#   nombre  col_new2
# 4  Karla        28
# 5   Juan        22

# %%
df = pddf.loc[pddf['nota'] <= 16, ['col_new2']]
df
# Out:
#    col_new2
# 0        32
# 4        28
# 5        22

# %%
pddf
# Out:
#     nombre  nota  Col_new  col_new2
# 0    Julio    16       13        32
# 1   Javier    17       45        34
# 2  Miluska    20       56        40
# 3    Deysi    18       23        36
# 4    Karla    14       45        28
# 5     Juan    11       87        22

# %%
df1 = pddf.loc[:, ['nombre']]
df1
# Out:
#     nombre
# 0    Julio
# 1   Javier
# 2  Miluska
# 3    Deysi
# 4    Karla
# 5     Juan

# %%
df1 = pddf.loc[pddf['nota'] == 17, ['nombre']]
df1
# Out:
#    nombre
# 1  Javier

# %%
df2 = pddf.loc['3':'4',:]
df2
# Out:
#   nombre  nota  Col_new  col_new2
# 3  Deysi    18       23        36
# 4  Karla    14       45        28

# %%
df3 = pddf.loc['3':'4']
df3
# Out:
#   nombre  nota  Col_new  col_new2
# 3  Deysi    18       23        36
# 4  Karla    14       45        28

# %%
pddf
# Out:
#     nombre  nota  Col_new  col_new2
# 0    Julio    16       13        32
# 1   Javier    17       45        34
# 2  Miluska    20       56        40
# 3    Deysi    18       23        36
# 4    Karla    14       45        28
# 5     Juan    11       87        22

# %%
df4 = pddf.iloc[[3,4,5], [0,1,2]]
df4
# Out:
#   nombre  nota  Col_new
# 3  Deysi    18       23
# 4  Karla    14       45
# 5   Juan    11       87

# %%
pddf
# Out:
#     nombre  nota  Col_new  col_new2
# 0    Julio    16       13        32
# 1   Javier    17       45        34
# 2  Miluska    20       56        40
# 3    Deysi    18       23        36
# 4    Karla    14       45        28
# 5     Juan    11       87        22

# %%
df5 = pddf.loc[[0,1], ['col_new2']]
df5
# Out:
#    col_new2
# 0        32
# 1        34

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
data
# Out:
# {'calories': [420, 380, 390], 'duration': [50, 40, 45]}

# %%
pddf2 = pd.DataFrame(data, index = ['day1', 'day2', 'day3'])
pddf2
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
df6 = pddf2.loc['day2':]
df6
# Out:
#       calories  duration
# day2       380        40
# day3       390        45

# %%
pddf
# Out:
#     nombre  nota  Col_new  col_new2
# 0    Julio    16       13        32
# 1   Javier    17       45        34
# 2  Miluska    20       56        40
# 3    Deysi    18       23        36
# 4    Karla    14       45        28
# 5     Juan    11       87        22

# %%
from tabulate import tabulate

# %%
pddf3 = pddf.reset_index(drop=True)
pddf3
# Out:
#     nombre  nota  Col_new  col_new2
# 0    Julio    16       13        32
# 1   Javier    17       45        34
# 2  Miluska    20       56        40
# 3    Deysi    18       23        36
# 4    Karla    14       45        28
# 5     Juan    11       87        22

# %%
pddf.dtypes
# Out:
# nombre      object
# nota         int64
# Col_new      int64
# col_new2     int64
# dtype: object

# %% [markdown]
# #Clase 4
